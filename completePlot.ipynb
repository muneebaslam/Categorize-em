# %%
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import bipartite
from networkx.algorithms import community
graph = nx.read_edgelist('C:/Users/Muneeb/Desktop/Al-Data/ALL111.txt')
'''c = bipartite.color(graph)
nx.set_node_attributes(graph,c,'bipartite')
type1 = {n for n, d in graph.nodes(data = True) if d['bipartite']==0}
type2 = {n for n, d in graph.nodes(data = True) if d['bipartite']==1}
g1 = bipartite.projected_graph(graph,type1)
g2 = bipartite.projected_graph(graph,type2)

#nx.draw(g1,with_labels=True)
#nx.draw(g2,with_labels=True)
print(nx.info(g2))
#pos1 = nx.spring_layout(g2, k=12, scale=2)

#ug = nx.to_undirected(g1)
#print('Number of nodes: ',nx.number_of_nodes(g2))
#print('Number of edges: ',nx.number_of_edges(g2))'''




options = {'node_color':'blue',
           'node_size':50,
           'line_color':'black',
           'linewidths': 0,
           'width':0.1}
catList= ['Music&Audio', 'Productivity', 'Auto&Vehicles','House&Home','Photography', 'Communication','Social','Lifestyle', 'Medical', 'Sports', 'Education', 'Shopping', 'Finance', 'News&Magazines', 'Food&Drink', 'Travel&Local', 'Weather', 'Simulation', 'Personalization', 'Tools', 'Books&Reference', 'Action', 'Entertainment']
color_map = []
for node in graph:
    if node in catList:
        color_map.append('maroon')
    else: color_map.append('green')


nx.draw(graph,with_labels = False,font_size = 5,node_size = 10,node_color = color_map ,width=1,pos = nx.spring_layout(graph))
#plt.savefig("ha.png",format='PNG')

plt.show()
