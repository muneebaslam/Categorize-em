# %%
file = open('C:/Users/Muneeb/Desktop/Discrete Structures CS-112/AppsData.txt','r')
outfile = open('C:/Users/Muneeb/Desktop/Discrete Structures CS-112/sam.txt','w')
music = []
productivity = []
medical = []
news = []
lifestyle = []
business = []
education = []
tools = []
foodDrink = []
travelLocal = []
weather = []
shopping = []
entertainment = []
finance = []
simulation = []
personalization = []
social = []
booksReference = []
action = []
autoVehicle = []
communication = []
houseHome = []
photograhy = []
mapsnavigation = []
sports = []
artDesign = []
puzzle = []
security = []
arcade = []
racing = []

for x in file:

    lst = x.split(',')

    if lst[1] == 'Music&Audio\n':
        music.append(lst[0])
    elif lst[1] == 'Productivity\n':
        productivity.append(lst[0])
    elif lst[1] == 'Medical\n':
        medical.append(lst[0])
    elif lst[1] == 'News&Magazines\n':
        news.append(lst[0])
    elif lst[1] == 'Lifestyle\n':
        lifestyle.append(lst[0])
    elif lst[1] == 'Business\n':
        business.append(lst[0])
    elif lst[1] == 'Education\n':
        education.append(lst[0])
    elif lst[1] == 'Tools\n':
        tools.append(lst[0])
    elif lst[1] == 'Food&Drink\n':
        foodDrink.append(lst[0])
    elif lst[1] == 'Travel&Local\n':
        travelLocal.append(lst[0])
    elif lst[1] == 'Weather\n':
        weather.append(lst[0])
    elif lst[1] == 'Shopping\n':
        shopping.append(lst[0])
    elif lst[1] == 'Entertainment\n':
        entertainment.append(lst[0])
    elif lst[1] == 'Finance\n':
        finance.append(lst[0])
    elif lst[1] == 'Simulation\n':
        simulation.append(lst[0])
    elif lst[1] == 'Personalization\n':
        personalization.append(lst[0])
    elif lst[1] == 'Social\n':
        social.append(lst[0])
    elif lst[1] == 'Books&Reference\n':
        booksReference.append(lst[0])
    elif lst[1] == 'Action\n':
        action.append(lst[0])
    elif lst[1] == 'Auto&Vehicles\n':
        autoVehicle.append(lst[0])
    elif lst[1] == 'Communication\n':
        communication.append(lst[0])
    elif lst[1] == 'House&Home\n':
        houseHome.append(lst[0])
    elif lst[1] == 'Photography\n':
        photograhy.append(lst[0])
    elif lst[1] == 'Maps&Navigation\n':
        mapsnavigation.append(lst[0])
    elif lst[1] == 'Sports\n':
        sports.append(lst[0])
    elif lst[1] == 'Art&Design\n':
        artDesign.append(lst[0])
    elif lst[1] == 'Puzzle\n':
        puzzle.append(lst[0])
    elif lst[1] == 'Security\n':
        security.append(lst[0])
    elif lst[1] == 'Arcade\n':
        arcade.append(lst[0])
    else:
        racing.append(lst[0])
file.close()

all_list = [music,productivity,medical,news,lifestyle,business,education,tools,foodDrink,travelLocal,weather,
            shopping,entertainment,finance,simulation,personalization,social,booksReference,
            action,autoVehicle,communication,houseHome,photograhy,mapsnavigation,sports,artDesign,
            puzzle,security,arcade]

for t in all_list:
    for b in t:
        outfile.write(b+' '+'####'+'\n')
    outfile.write('@@@@@@@'+'\n')
outfile.close()
